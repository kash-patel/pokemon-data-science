# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
with open("./data/vgc2023s1/team-pokemon.json", "r") as f:
  team_pokemon = json.load(f)

team_pokemon_df = pd.DataFrame(team_pokemon)
team_pokemon_df
# Out:
#     team_id  rank    species showdown_pokedex_name type_1  type_2  base_hp  \
# 0       284     1    Dondozo               dondozo  grass  poison      114
# 1       284     1  Tatsugiri             tatsugiri  grass  poison      114
# 2       284     1  Gholdengo             gholdengo  grass  poison      114
# 3       284     1    Murkrow               murkrow  grass  poison      114
# 4       284     1  Dragonite             dragonite  grass  poison      114
# ..      ...   ...        ...                   ...    ...     ...      ...
# 379     283    32  Kingambit             kingambit  grass  poison      114
# 380     283    32   Pelipper              pelipper  grass  poison      114
# 381     283    32  Gholdengo             gholdengo  grass  poison      114
# 382     283    32    Mimikyu               mimikyu  grass  poison      114
# 383     283    32  Amoonguss             amoonguss  grass  poison      114
#
#      base_atk  base_def  base_spa  base_spd  base_spe            item  \
# 0          85        70        85        80        30       leftovers
# 1          85        70        85        80        30    choice-scarf
# 2          85        70        85        80        30    choice-specs
# 3          85        70        85        80        30        eviolite
# 4          85        70        85        80        30    assault-vest
# ..        ...       ...       ...       ...       ...             ...
# 379        85        70        85        80        30    assault-vest
# 380        85        70        85        80        30        life-orb
# 381        85        70        85        80        30       leftovers
# 382        85        70        85        80        30  safety-goggles
# 383        85        70        85        80        30    sitrus-berry
#
#           ability tera_type   nature         move_1            move_2  \
# 0         unaware    dragon    jolly     wave-crash        substitute
# 1       commander     water   modest   draco-meteor       muddy-water
# 2    good-as-gold     steel   modest   make-it-rain       shadow-ball
# 3       prankster     ghost     calm       tailwind         foul-play
# 4     inner-focus    flying  adamant  extreme-speed  stomping-tantrum
# ..            ...       ...      ...            ...               ...
# 379       defiant    flying   nature  kowtow-cleave          low-kick
# 380       drizzle     fairy   nature      hurricane        wide-guard
# 381  good-as-gold     steel   nature   make-it-rain           protect
# 382      disguise     fairy   nature     play-rough             curse
# 383   regenerator      dark   nature          spore       rage-powder
#
#            move_3       move_4
# 0        order-up      protect
# 1        icy-wind   sleep-talk
# 2     thunderbolt    power-gem
# 3           quash         haze
# 4      tera-blast     low-kick
# ..            ...          ...
# 379  sucker-punch    iron-head
# 380    hydro-pump     tailwind
# 381    nasty-plot  shadow-ball
# 382  shadow-sneak   trick-room
# 383    leaf-storm  pollen-puff
#
# [384 rows x 20 columns]

# %%
plt.boxplot(team_pokemon_df[["base_hp", "base_atk"]])
plt.show()
